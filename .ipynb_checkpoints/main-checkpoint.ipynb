# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import joblib
from sklearn.metrics import accuracy_score

# part one: finding and loading the data 
sp_data=pd.read_csv("sp500_stocks.csv")
sp_data
# Out:
#                Date Symbol   Adj Close       Close        High         Low  \
# 0        2010-01-04    MMM   59.318886   83.019997   83.449997   82.669998
# 1        2010-01-05    MMM   58.947342   82.500000   83.230003   81.699997
# 2        2010-01-06    MMM   59.783295   83.669998   84.599998   83.510002
# 3        2010-01-07    MMM   59.826176   83.730003   83.760002   82.120003
# 4        2010-01-08    MMM   60.247749   84.320000   84.320000   83.300003
# ...             ...    ...         ...         ...         ...         ...
# 1641284  2022-12-12    ZTS  152.860001  152.860001  154.470001  152.179993
# 1641285  2022-12-13    ZTS  154.970001  154.970001  158.479996  152.080002
# 1641286  2022-12-14    ZTS  151.779999  151.779999  156.100006  151.229996
# 1641287  2022-12-15    ZTS  148.710007  148.710007  151.350006  148.539993
# 1641288  2022-12-16    ZTS  144.460007  144.460007  147.570007  143.919998
#
#                Open     Volume
# 0         83.089996  3043700.0
# 1         82.800003  2847000.0
# 2         83.879997  5268500.0
# 3         83.320000  4470100.0
# 4         83.690002  3405800.0
# ...             ...        ...
# 1641284  154.070007  1851800.0
# 1641285  158.210007  3655900.0
# 1641286  153.770004  2182000.0
# 1641287  149.509995  1947400.0
# 1641288  147.309998  5216000.0
#
# [1641289 rows x 8 columns]

# %%
x=sp_data.drop(columns=['Close'])
x

# %%
y=sp_data['Close']
y
